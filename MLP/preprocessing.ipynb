# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('/content/Dry_Bean_Dataset.xlsx')

# %%
pd.set_option('display.max_columns', None)
data.head()
# Out:
#      Area  Perimeter  MajorAxisLength  MinorAxisLength  roundnes   Class
# 0  114004   1279.356       451.361256       323.747996  0.875280  BOMBAY
# 1  117034   1265.926       425.923787       351.215109  0.917710  BOMBAY
# 2  126503   1326.959       475.772459       339.381887  0.902809  BOMBAY
# 3  128118   1360.135       504.024964              NaN  0.870274  BOMBAY
# 4  129409   1348.888       484.364424       341.172659  0.893763  BOMBAY

# %%
data.shape
# Out:
# (150, 6)

# %%
data.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2962204f287d> in <cell line: 1>()
# ----> 1 data.isnull().sum()
#
# NameError: name 'data' is not defined

# %% [markdown]
# -feh null value wahda fl minor axis length

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             150 non-null    int64
#  1   Perimeter        150 non-null    float64
#  2   MajorAxisLength  150 non-null    float64
#  3   MinorAxisLength  149 non-null    float64
#  4   roundnes         150 non-null    float64
#  5   Class            150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
##el classes bs heya el hn3mlha encoding

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Class'].value_counts()
# Out:
# BOMBAY    50
# CALI      50
# SIRA      50
# Name: Class, dtype: int64

# %%
category_means = data.groupby('Class')['MinorAxisLength'].mean()

# %%
category_means
# Out:
# Class
# BOMBAY    344.935256
# CALI      207.137964
# SIRA      170.758309
# Name: MinorAxisLength, dtype: float64

# %%
data['MinorAxisLength'] = data.groupby('Class')['MinorAxisLength'].transform(lambda x: x.fillna(x.mean()))

# %%
data.head()
# Out:
#      Area  Perimeter  MajorAxisLength  MinorAxisLength  roundnes   Class
# 0  114004   1279.356       451.361256       323.747996  0.875280  BOMBAY
# 1  117034   1265.926       425.923787       351.215109  0.917710  BOMBAY
# 2  126503   1326.959       475.772459       339.381887  0.902809  BOMBAY
# 3  128118   1360.135       504.024964       344.935256  0.870274  BOMBAY
# 4  129409   1348.888       484.364424       341.172659  0.893763  BOMBAY

# %%
columns=data.columns

# %%
for col in columns:
    if not (data[col].dtype == 'object'):
        sns.boxplot(x=data[col])
        plt.show()

# %%
##roundnes have some outliers bs hnsbhom 3shan homa actual values

# %%
for col in columns:
  if not (data[col].dtype == 'object'):
    sns.histplot(x = data[col], kde=True)
    plt.show()

# %% [markdown]
# ##analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with the specified columns

# Set up the figure and axes
plt.figure(figsize=(12, 8))

# Create a bar plot for the relationship between 'Area' and 'Class'
sns.barplot(x='Class', y='Area', data=data, palette='viridis', ci=None)
plt.title('Bar Plot of Class based on Area')
plt.xlabel('Class')
plt.ylabel('Mean Area')
plt.show()
# Out:
# <ipython-input-18-8f96a105fc3f>:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Class', y='Area', data=data, palette='viridis', ci=None)
# <ipython-input-18-8f96a105fc3f>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Class', y='Area', data=data, palette='viridis', ci=None)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with the specified columns

# Set up the figure and axes
plt.figure(figsize=(12, 8))

# Create a bar plot for the relationship between 'Perimeter' and 'Class'
sns.barplot(x='Class', y='Perimeter', data=data, palette='viridis', ci=None)
plt.title('Bar Plot of Class based on Perimeter')
plt.xlabel('Class')
plt.ylabel('Mean Perimeter')
plt.show()
# Out:
# <ipython-input-19-de3a38b0050d>:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Class', y='Perimeter', data=data, palette='viridis', ci=None)
# <ipython-input-19-de3a38b0050d>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Class', y='Perimeter', data=data, palette='viridis', ci=None)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with the specified columns

# Set up the figure and axes
plt.figure(figsize=(12, 8))

# Create a bar plot for the relationship between 'MajorAxisLength' and 'Class'
sns.barplot(x='Class', y='MajorAxisLength', data=data, palette='viridis', ci=None)
plt.title('Bar Plot of Class based on MajorAxisLength')
plt.xlabel('Class')
plt.ylabel('Mean MajorAxisLength')
plt.show()
# Out:
# <ipython-input-20-b7b40c9ca3ab>:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Class', y='MajorAxisLength', data=data, palette='viridis', ci=None)
# <ipython-input-20-b7b40c9ca3ab>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Class', y='MajorAxisLength', data=data, palette='viridis', ci=None)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with the specified columns

# Set up the figure and axes
plt.figure(figsize=(12, 8))

# Create a bar plot for the relationship between 'MajorAxisLength' and 'Class'
sns.barplot(x='Class', y='MinorAxisLength', data=data, palette='viridis', ci=None)
plt.title('Bar Plot of Class based on MajorAxisLength')
plt.xlabel('Class')
plt.ylabel('Mean MinorAxisLength')
plt.show()
# Out:
# <ipython-input-21-8fff7ba12a43>:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Class', y='MinorAxisLength', data=data, palette='viridis', ci=None)
# <ipython-input-21-8fff7ba12a43>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Class', y='MinorAxisLength', data=data, palette='viridis', ci=None)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with the specified columns

# Set up the figure and axes
plt.figure(figsize=(12, 8))

# Create a bar plot for the relationship between 'MajorAxisLength' and 'Class'
sns.barplot(x='Class', y='roundnes', data=data, palette='viridis', ci=None)
plt.title('Bar Plot of Class based on MajorAxisLength')
plt.xlabel('Class')
plt.ylabel('Mean roundnes')
plt.show()
# Out:
# <ipython-input-22-79e62571b6cc>:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Class', y='roundnes', data=data, palette='viridis', ci=None)
# <ipython-input-22-79e62571b6cc>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Class', y='roundnes', data=data, palette='viridis', ci=None)

# %%
columns_to_normalize = ['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength']

# Min-Max scaling for specified columns
for column in columns_to_normalize:
    min_val = data[column].min()
    max_val = data[column].max()
    data[column] = (data[column] - min_val) / (max_val - min_val)

# %%
data.head()
# Out:
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  roundnes   Class
# 0  0.732809   0.768721         0.708946         0.758616  0.875280  BOMBAY
# 1  0.759728   0.751831         0.626053         0.884181  0.917710  BOMBAY
# 2  0.843852   0.828587         0.788494         0.830086  0.902809  BOMBAY
# 3  0.858200   0.870310         0.880560         0.855473  0.870274  BOMBAY
# 4  0.869670   0.856166         0.816493         0.838272  0.893763  BOMBAY

# %%
df = pd.DataFrame(data)

# Save DataFrame to Excel
df.to_excel('final_file.xlsx', index=True)
