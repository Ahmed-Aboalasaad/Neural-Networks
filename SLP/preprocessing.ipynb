# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("./Dry_Bean_Dataset.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df=pd.read_csv("./final_file.csv")
#
# File c:\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# roundnes           0
# Class              0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0      Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# 0           0  0.732809   0.768721         0.708946         0.758616
# 1           1  0.759728   0.751831         0.626053         0.884181
# 2           2  0.843852   0.828587         0.788494         0.830086
# 3           3  0.858200   0.870310         0.880560         0.855473
# 4           4  0.869670   0.856166         0.816493         0.838272
#
#    roundnes   Class
# 0  0.875280  BOMBAY
# 1  0.917710  BOMBAY
# 2  0.902809  BOMBAY
# 3  0.870274  BOMBAY
# 4  0.893763  BOMBAY

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

one_hot_encoded_data = pd.get_dummies(df, columns = ['Class'])
# Assuming 'df' is your DataFrame containing the one-hot encoded 'Class' columns
# Replace True/False values with 1/0
one_hot_encoded_data[['Class_BOMBAY', 'Class_CALI', 'Class_SIRA']] = one_hot_encoded_data[['Class_BOMBAY', 'Class_CALI', 'Class_SIRA']].replace({True: 1, False: 0})


one_hot_encoded_data
# Out:
#      Unnamed: 0      Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# 0             0  0.732809   0.768721         0.708946         0.758616
# 1             1  0.759728   0.751831         0.626053         0.884181
# 2             2  0.843852   0.828587         0.788494         0.830086
# 3             3  0.858200   0.870310         0.880560         0.855473
# 4             4  0.869670   0.856166         0.816493         0.838272
# ..          ...       ...        ...              ...              ...
# 145         145  0.035155   0.054343         0.107686         0.055432
# 146         146  0.035421   0.056568         0.092225         0.070607
# 147         147  0.035910   0.050349         0.084606         0.077751
# 148         148  0.035990   0.053353         0.095986         0.071205
# 149         149  0.036549   0.056052         0.093796         0.071731
#
#      roundnes  Class_BOMBAY  Class_CALI  Class_SIRA
# 0    0.875280             1           0           0
# ...

# %%
one_hot_encoded_data
# Out:
#      Unnamed: 0      Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# 0             0  0.732809   0.768721         0.708946         0.758616
# 1             1  0.759728   0.751831         0.626053         0.884181
# 2             2  0.843852   0.828587         0.788494         0.830086
# 3             3  0.858200   0.870310         0.880560         0.855473
# 4             4  0.869670   0.856166         0.816493         0.838272
# ..          ...       ...        ...              ...              ...
# 145         145  0.035155   0.054343         0.107686         0.055432
# 146         146  0.035421   0.056568         0.092225         0.070607
# 147         147  0.035910   0.050349         0.084606         0.077751
# 148         148  0.035990   0.053353         0.095986         0.071205
# 149         149  0.036549   0.056052         0.093796         0.071731
#
#      roundnes  Class_BOMBAY  Class_CALI  Class_SIRA
# 0    0.875280             1           0           0
# ...

# %%
df = pd.DataFrame(one_hot_encoded_data)

# Save DataFrame to Excel
one_hot_encoded_data.to_excel('dry_beans_final2.xlsx', index=True)
